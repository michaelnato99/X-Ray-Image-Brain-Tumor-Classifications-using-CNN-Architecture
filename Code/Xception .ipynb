# %%
# %%
# IMPORT LIBRARIES

# GENERAL
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# PATH PROCESS
import os
import os.path
from pathlib import Path
import glob
import itertools

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Input, Conv2D, SeparableConv2D, \
    Add, Dense, BatchNormalization, ReLU, MaxPool2D, GlobalAvgPool2D
from tensorflow.keras.preprocessing import image

from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint

# %%
# %%
# PATH & LABEL PROCESS

# Main path
data_path = Path('/Users/macbookpro/Desktop/Brain Tumor Classification')

# Listing subdirectories
file_path = list(data_path.glob('**/*.jpg'))

# Mapping the labels
img_labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], file_path))

# Transformation to series
files = pd.Series(file_path, name="files", dtype='object').astype(str)
labels = pd.Series(img_labels, name="category", dtype='object')

# Concatenating series to train_data dataframe
train_df = pd.concat([files, labels], axis=1)

# Number of categories
print(train_df['category'].value_counts())
# Shuffling
train_df = train_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Checking results
print(train_df.head())
print(train_df['category'].value_counts())
print(train_df.info())
# Out:
# meningioma_tumor    937
# glioma_tumor        926
# pituitary_tumor     901
# no_tumor            500
# Name: category, dtype: int64
#                                                files          category
# 0  /Users/macbookpro/Desktop/Brain Tumor Classifi...      glioma_tumor
# 1  /Users/macbookpro/Desktop/Brain Tumor Classifi...          no_tumor
# 2  /Users/macbookpro/Desktop/Brain Tumor Classifi...  meningioma_tumor
# 3  /Users/macbookpro/Desktop/Brain Tumor Classifi...          no_tumor
# 4  /Users/macbookpro/Desktop/Brain Tumor Classifi...  meningioma_tumor
# meningioma_tumor    937
# glioma_tumor        926
# pituitary_tumor     901
# no_tumor            500
# Name: category, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3264 entries, 0 to 3263
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   files     3264 non-null   object
#  1   category  3264 non-null   object
# dtypes: object(2)
# memory usage: 51.1+ KB
# None

# %%
# %%
# DATA PREPARATION

# Splitting train and test
train_data, test_data = train_test_split(train_df, train_size=0.85, random_state=42)

print("Train shape: ", train_data.shape)
print("Test shape: ", test_data.shape)

print(train_data["category"].value_counts())
print(test_data["category"].value_counts())

# Converting the label to a numeric format
test_images = LabelEncoder().fit_transform(test_data["category"])
# Out:
# Train shape:  (2774, 2)
# Test shape:  (490, 2)
# meningioma_tumor    791
# glioma_tumor        785
# pituitary_tumor     770
# no_tumor            428
# Name: category, dtype: int64
# meningioma_tumor    146
# glioma_tumor        141
# pituitary_tumor     131
# no_tumor             72
# Name: category, dtype: int64

# %%
# %%
# Image generator
train_generator = ImageDataGenerator(rescale=1. / 255,
                                     shear_range=0.3,
                                     zoom_range=0.2,
                                     rotation_range=30,
                                     width_shift_range=0.1,
                                     height_shift_range=0.1,
                                     horizontal_flip=True,
                                     vertical_flip=True,
                                     validation_split=0.15)

test_generator = ImageDataGenerator(rescale=1. / 255)

# %%
# %%
# Applying generator and transformation to tensor
print("PREPARING THE TRAINING DATA:")
train_images = train_generator.flow_from_dataframe(dataframe=train_data,
                                                   x_col="files",
                                                   y_col="category",
                                                   target_size=(256, 256),
                                                   color_mode="rgb",
                                                   class_mode="categorical",
                                                   batch_size=16,
                                                   subset="training")

print("PREPARING THE VALIDATION DATA:")
valid_images = train_generator.flow_from_dataframe(dataframe=train_data,
                                                   x_col="files",
                                                   y_col="category",
                                                   target_size=(256, 256),
                                                   color_mode="rgb",
                                                   class_mode="categorical",
                                                   batch_size=16,
                                                   subset="validation")
print("PREPARING THE TEST DATA:")
test_images = test_generator.flow_from_dataframe(dataframe=test_data,
                                                 x_col="files",
                                                 y_col="category",
                                                 target_size=(256, 256),
                                                 color_mode="rgb",
                                                 class_mode="categorical",
                                                 batch_size=16)
train_images.class_indices
# Out:
# PREPARING THE TRAINING DATA:
# Found 2358 validated image filenames belonging to 4 classes.
# PREPARING THE VALIDATION DATA:
# Found 416 validated image filenames belonging to 4 classes.
# PREPARING THE TEST DATA:
# Found 490 validated image filenames belonging to 4 classes.
# {'glioma_tumor': 0, 'meningioma_tumor': 1, 'no_tumor': 2, 'pituitary_tumor': 3}

# %%
# %%
# Checking
print("Checking the training data:")
for data_batch, label_batch in train_images:
    print("DATA SHAPE: ", data_batch.shape)
    print("LABEL SHAPE: ", label_batch.shape)
    break

print("Checking the validation data:")
for data_batch, label_batch in valid_images:
    print("DATA SHAPE: ", data_batch.shape)
    print("LABEL SHAPE: ", label_batch.shape)
    break

print("Checking the test data:")
for data_batch, label_batch in test_images:
    print("DATA SHAPE: ", data_batch.shape)
    print("LABEL SHAPE: ", label_batch.shape)
    break
# Out:
# Checking the training data:
# DATA SHAPE:  (16, 256, 256, 3)
# LABEL SHAPE:  (16, 4)
# Checking the validation data:
# DATA SHAPE:  (16, 256, 256, 3)
# LABEL SHAPE:  (16, 4)
# Checking the test data:
# DATA SHAPE:  (16, 256, 256, 3)
# LABEL SHAPE:  (16, 4)

# %%
# %%
# EVALUATION AND VISUALIZATION OF MODEL PARAMETERS

def learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(20, 8))
    plt.grid(True)
    plt.title('Learning curves')
    plt.gca().set_ylim(0, 1)
    plt.show()


def evaluation_model(history):
    fig, (axL, axR) = plt.subplots(ncols=2, figsize=(20, 8))
    axL.plot(history.history['loss'], label="Training loss")
    axL.plot(history.history['val_loss'], label="Validation loss")
    axL.set_title('Training and Validation loss')
    axL.set_xlabel('Epochs')
    axL.set_ylabel('Loss')
    axL.legend(loc='upper right')

    axR.plot(history.history['accuracy'], label="Training accuracy")
    axR.plot(history.history['val_accuracy'], label="Validation accuracy")
    axR.set_title('Training and Validation accuracy')
    axR.set_xlabel('Epoch')
    axR.set_ylabel('Accuracy')
    axR.legend(loc='upper right')

    plt.show()


def model_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15):
    # Create the confustion matrix
    cm = confusion_matrix(y_true, y_pred)
    cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
    n_classes = cm.shape[0]

    # Plot the figure and make it pretty
    fig, ax = plt.subplots(figsize=figsize)
    cax = ax.matshow(cm, cmap=plt.cm.Blues)  # colors will represent how 'correct' a class is, darker == better
    fig.colorbar(cax)

    # Are there a list of classes?
    if classes:
        labels = classes
    else:
        labels = np.arange(cm.shape[0])

    # Label the axes
    ax.set(title="Confusion Matrix",
           xlabel="Predicted label",
           ylabel="True label",
           xticks=np.arange(n_classes),  # create enough axis slots for each class
           yticks=np.arange(n_classes),
           xticklabels=labels,  # axes will labeled with class names (if they exist) or ints
           yticklabels=labels)

    # Make x-axis labels appear on bottom
    ax.xaxis.set_label_position("bottom")
    ax.xaxis.tick_bottom()

    # Set the threshold for different colors
    threshold = (cm.max() + cm.min()) / 2.

    # Plot the text on each cell
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j] * 100:.1f}%)",
                 horizontalalignment="center",
                 color="white" if cm[i, j] > threshold else "black",
                 size=text_size)
    plt.show()

# %%
# %%
# AUXILIARY FUNCTIONS

# Conv-BatchNorm block
def conv_bn(x, filters, kernel_size, strides=1):
    x = Conv2D(filters=filters,
               kernel_size=kernel_size,
               strides=strides,
               padding='same',
               use_bias=False)(x)
    x = BatchNormalization()(x)
    return x


# SeparableConv-BatchNorm block
def sep_bn(x, filters, kernel_size, strides=1):
    x = SeparableConv2D(filters=filters,
                        kernel_size=kernel_size,
                        strides=strides,
                        padding='same',
                        use_bias=False)(x)
    x = BatchNormalization()(x)
    return x

# %%
# %%
# MODEL: XCEPTION

# ENTRY FLOW
def entry_flow(x):
    x = conv_bn(x, filters=32, kernel_size=3, strides=2)
    x = ReLU()(x)
    x = conv_bn(x, filters=64, kernel_size=3)
    tensor = ReLU()(x)

    x = sep_bn(tensor, filters=128, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=128, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

    tensor = conv_bn(tensor, filters=128, kernel_size=1, strides=2)

    x = Add()([tensor, x])

    x = ReLU()(x)
    x = sep_bn(x, filters=256, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=256, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

    tensor = conv_bn(tensor, filters=256, kernel_size=1, strides=2)

    x = Add()([tensor, x])

    x = ReLU()(x)
    x = sep_bn(x, filters=728, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=728, kernel_size=3)
    x = MaxPool2D(pool_size=3, strides=2, padding='same')(x)

    tensor = conv_bn(tensor, filters=728, kernel_size=1, strides=2)

    x = Add()([tensor, x])

    return x

# %%
# MIDDLE FLOW
def middle_flow(tensor):
    for _ in range(8):
        x = ReLU()(tensor)
        x = sep_bn(x, filters=728, kernel_size=3)
        x = ReLU()(x)
        x = sep_bn(x, filters=728, kernel_size=3)
        x = ReLU()(x)
        x = sep_bn(x, filters=728, kernel_size=3)

        tensor = Add()([tensor, x])

    return tensor

# %%
# EXIT FLOW
def exit_flow(tensor):
    x = ReLU()(tensor)
    x = sep_bn(x, filters=728, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=1024, kernel_size=3)
    x = MaxPool2D(3, strides=2, padding='same')(x)

    tensor = conv_bn(tensor, filters=1024, kernel_size=1, strides=2)

    x = Add()([tensor, x])

    x = sep_bn(x, filters=1536, kernel_size=3)
    x = ReLU()(x)
    x = sep_bn(x, filters=2048, kernel_size=3)
    x = ReLU()(x)

    x = GlobalAvgPool2D()(x)

    x = Dense(units=4, activation='softmax')(x)

    return x

# %%
# %%
# MODEL
input = Input(shape=(256, 256, 3))

x = entry_flow(input)
x = middle_flow(x)
output = exit_flow(x)

model = Model(inputs=input, outputs=output)

model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=["accuracy"])
model.summary()
# Out:
# 2021-10-18 00:16:21.737511: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-18 00:16:21.737787: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 4. Tune using inter_op_parallelism_threads for best performance.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 128, 128, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 64) 18432       re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 128, 128, 64) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 128, 128, 128 8768        re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 128 512         separable_conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 128, 128, 128 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 128, 128, 128 17536       re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 128)  8192        re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 128 512         separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 128)  512         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 128)  0           batch_normalization_4[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 64, 64, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 64, 64, 256)  33920       re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 256)  1024        separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 64, 64, 256)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 64, 64, 256)  67840       re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 256)  32768       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 256)  1024        separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 256)  1024        conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 256)  0           batch_normalization_7[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 32, 32, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 32, 32, 728)  188672      re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 728)  2912        separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 32, 32, 728)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 32, 32, 728)  536536      re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 728)  186368      batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 728)  2912        separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 728)  2912        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 728)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 728)  0           batch_normalization_10[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 16, 16, 728)  0           add_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 16, 16, 728)  536536      re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# re_lu_8 (ReLU)                  (None, 16, 16, 728)  0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 16, 16, 728)  536536      re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_9 (ReLU)                  (None, 16, 16, 728)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_8 (SeparableCo (None, 16, 16, 728)  536536      re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 728)  0           add_2[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# re_lu_10 (ReLU)                 (None, 16, 16, 728)  0           add_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_9 (SeparableCo (None, 16, 16, 728)  536536      re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_9[0][0]
# __________________________________________________________________________________________________
# re_lu_11 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_10 (SeparableC (None, 16, 16, 728)  536536      re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_10[0][0]
# __________________________________________________________________________________________________
# re_lu_12 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_11 (SeparableC (None, 16, 16, 728)  536536      re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 16, 16, 728)  0           add_3[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# re_lu_13 (ReLU)                 (None, 16, 16, 728)  0           add_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_12 (SeparableC (None, 16, 16, 728)  536536      re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_12[0][0]
# __________________________________________________________________________________________________
# re_lu_14 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_13 (SeparableC (None, 16, 16, 728)  536536      re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_13[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_14 (SeparableC (None, 16, 16, 728)  536536      re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 728)  0           add_4[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# re_lu_16 (ReLU)                 (None, 16, 16, 728)  0           add_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_15 (SeparableC (None, 16, 16, 728)  536536      re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_15[0][0]
# __________________________________________________________________________________________________
# re_lu_17 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_16 (SeparableC (None, 16, 16, 728)  536536      re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_16[0][0]
# __________________________________________________________________________________________________
# re_lu_18 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_17 (SeparableC (None, 16, 16, 728)  536536      re_lu_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 728)  0           add_5[0][0]
#                                                                  batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# re_lu_19 (ReLU)                 (None, 16, 16, 728)  0           add_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_18 (SeparableC (None, 16, 16, 728)  536536      re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_18[0][0]
# __________________________________________________________________________________________________
# re_lu_20 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_19 (SeparableC (None, 16, 16, 728)  536536      re_lu_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_19[0][0]
# __________________________________________________________________________________________________
# re_lu_21 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_20 (SeparableC (None, 16, 16, 728)  536536      re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 728)  0           add_6[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# re_lu_22 (ReLU)                 (None, 16, 16, 728)  0           add_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_21 (SeparableC (None, 16, 16, 728)  536536      re_lu_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_21[0][0]
# __________________________________________________________________________________________________
# re_lu_23 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_22 (SeparableC (None, 16, 16, 728)  536536      re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_22[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_23 (SeparableC (None, 16, 16, 728)  536536      re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 728)  0           add_7[0][0]
#                                                                  batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 16, 16, 728)  0           add_8[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_24 (SeparableC (None, 16, 16, 728)  536536      re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_24[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_25 (SeparableC (None, 16, 16, 728)  536536      re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_25[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_26 (SeparableC (None, 16, 16, 728)  536536      re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_26[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 728)  0           add_8[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 16, 16, 728)  0           add_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_27 (SeparableC (None, 16, 16, 728)  536536      re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_27[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_28 (SeparableC (None, 16, 16, 728)  536536      re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_28[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_29 (SeparableC (None, 16, 16, 728)  536536      re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 728)  0           add_9[0][0]
#                                                                  batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 16, 16, 728)  0           add_10[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_30 (SeparableC (None, 16, 16, 728)  536536      re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16, 16, 728)  2912        separable_conv2d_30[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 16, 16, 728)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_31 (SeparableC (None, 16, 16, 1024) 752024      re_lu_32[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 1024)   745472      add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 16, 16, 1024) 4096        separable_conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 1024)   4096        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 1024)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 1024)   0           batch_normalization_37[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_32 (SeparableC (None, 8, 8, 1536)   1582080     add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 1536)   6144        separable_conv2d_32[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 8, 8, 1536)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_33 (SeparableC (None, 8, 8, 2048)   3159552     re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 2048)   8192        separable_conv2d_33[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 8, 8, 2048)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           re_lu_34[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 4)            8196        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 20,869,676
# Trainable params: 20,815,148
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
model.save('Xception_Sintesis_Manual')
# Out:
# 2021-10-18 00:17:08.232108: W tensorflow/python/util/util.cc:299] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: Xception_Sintesis_Manual/assets

# %%
# %%
# Train model
early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=5,
                                                     restore_best_weights=True)

history = model.fit(train_images,
                    validation_data=valid_images,
                    epochs=5,
                    callbacks=[early_stopping_cb])
# Out:
# 2021-10-13 06:02:53.737128: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 38 of 148
# 2021-10-13 06:03:03.754632: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 76 of 148
# 2021-10-13 06:03:13.555997: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 113 of 148
# 2021-10-13 06:03:22.663605: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:193] Shuffle buffer filled.
# Train for 148 steps, validate for 26 steps
# Epoch 1/5
# 2021-10-13 06:03:44.903759: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 40 of 148
# 2021-10-13 06:03:54.685223: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 78 of 148
# 2021-10-13 06:04:04.749886: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 117 of 148
# 2021-10-13 06:04:12.595772: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:193] Shuffle buffer filled.
# 148/148 [==============================] - 918s 6s/step - loss: 1.2504 - accuracy: 0.4779 - val_loss: 1.3825 - val_accuracy: 0.2524
# Epoch 2/5
# 2021-10-13 06:18:51.600296: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 38 of 148
# 2021-10-13 06:19:01.572230: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 76 of 148
# 2021-10-13 06:19:11.659496: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 113 of 148
# 2021-10-13 06:19:21.530302: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:193] Shuffle buffer filled.
# 148/148 [==============================] - 909s 6s/step - loss: 1.0139 - accuracy: 0.5844 - val_loss: 1.3951 - val_accuracy: 0.2548
# Epoch 3/5
# 2021-10-13 06:34:00.346928: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 39 of 148
# 2021-10-13 06:34:10.332061: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 77 of 148
# 2021-10-13 06:34:20.411729: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 115 of 148
# 2021-10-13 06:34:29.020479: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:193] Shuffle buffer filled.
# 148/148 [==============================] - 899s 6s/step - loss: 0.8980 - accuracy: 0.6378 - val_loss: 1.1069 - val_accuracy: 0.5312
# Epoch 4/5
# 2021-10-13 06:48:59.835633: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 39 of 148
# 2021-10-13 06:49:09.836114: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 77 of 148
# 2021-10-13 06:49:19.592955: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 114 of 148
# 2021-10-13 06:49:28.508094: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:193] Shuffle buffer filled.
# 148/148 [==============================] - 892s 6s/step - loss: 0.7489 - accuracy: 0.7226 - val_loss: 2.8740 - val_accuracy: 0.3774
# Epoch 5/5
# 2021-10-13 07:03:51.629277: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 39 of 148
# 2021-10-13 07:04:01.529153: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 75 of 148
# 2021-10-13 07:04:11.521471: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 110 of 148
# 2021-10-13 07:04:21.582928: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:143] Filling up shuffle buffer (this may take a while): 145 of 148
# 2021-10-13 07:04:22.346553: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:193] Shuffle buffer filled.
# 148/148 [==============================] - 947s 6s/step - loss: 0.6852 - accuracy: 0.7494 - val_loss: 1.5153 - val_accuracy: 0.5312

# %%
# %%
# EVALUATION RESULT
# Learning curves
learning_curves(history)

# Evaluation model
evaluation_model(history)

# Evaluate the model on the test set
evaluate_1 = model.evaluate(test_images, verbose=2)

# Predicting the test set results
y_pred = model.predict(test_images)
y_pred_class = np.argmax(y_pred, axis=1)

prediction_class = LabelEncoder().fit_transform(test_data["category"])

# Confusion matrix
model_confusion_matrix(prediction_class, y_pred_class)
# Out:
# 31/31 - 70s - loss: 1.7658 - accuracy: 0.5184

# %%
TP=2
TN=58+41+47+24+26+20+47+33+50
FP=1+47+33
FN=35+52+52

acc=(TP+TN)/(FP+FN+TP+TN)
miss=(FP+FN)/(FP+FN+TP+TN)
precision=TP/(TP+FP)
recall=TP/(TP+FN)
specificity=TN/(TN+FP)
F1_score=2*precision*recall/(precision+recall)

print("Accuracy:")
print(acc)
print("Misclassification Rate:")
print(miss)
print("Precision:")
print(precision)
print("Recall:")
print(recall)
print("specificity:")
print(specificity)
print("F1-Score:")
print(F1_score)
# Out:
# Accuracy:
# 0.6126760563380281
# Misclassification Rate:
# 0.3873239436619718
# Precision:
# 0.024096385542168676
# Recall:
# 0.014184397163120567
# specificity:
# 0.810304449648712
# F1-Score:
# 0.017857142857142856
